# %%
# https://github.com/JohnSnowLabs/spark-nlp-workshop/blob/master/tutorials/streamlit_notebooks/NER_FR.ipynb
import json
import pandas as pd
import numpy as np

from pyspark.ml import Pipeline
from pyspark.sql import SparkSession
import pyspark.sql.functions as F
from pyspark.sql.window import Window
from sparknlp.annotator import *
from sparknlp.base import *
import sparknlp
from sparknlp.pretrained import PretrainedPipeline

spark = sparknlp.start()

# %% [markdown]
# # Data set

# %%
path = "data/data_set_final.csv"

# %%
df = spark.read.option("header","true").csv(path)
df = spark.createDataFrame(df.head(1000))

# %%
data = df.select('adresse').toDF("text")
data.show(n=5, truncate = False)
# Out:
# +-------------------------------------+
# |text                                 |
# +-------------------------------------+
# |6 Place du Pese Lait                 |
# |1 Les Granges                        |
# |2 Les Granges                        |
# |10 Les Granges                       |
# |1082 Chemin de la Ferm de la Montagne|
# +-------------------------------------+
# only showing top 5 rows

# %%
empty_df = spark.createDataFrame([['']]).toDF('text')

# %% [markdown]
# # 1. Document Assembler and Tokenizer

# %%
document_assembler = DocumentAssembler() \
    .setInputCol('text') \
    .setOutputCol('document')

tokenizer = Tokenizer() \
    .setInputCols(['document']) \
    .setOutputCol('token')

# %%
pipeline_1 = Pipeline(stages=[
    document_assembler, 
    tokenizer
])
model_1 = pipeline_1.fit(empty_df)
result_1 = model_1.transform(data)

# %%
# https://nlp.johnsnowlabs.com/docs/en/concepts#documentassembler-getting-data-in
# https://nlp.johnsnowlabs.com/api/python/reference/autosummary/sparknlp.base.DocumentAssembler.html
# https://nlp.johnsnowlabs.com/api/python/modules/sparknlp/base.html#DocumentAssembler
result_1.select("document").show(n = 5, truncate = False)
# Out:
# +-------------------------------------------------------------------------------+
# |document                                                                       |
# +-------------------------------------------------------------------------------+
# |[{document, 0, 19, 6 Place du Pese Lait, {sentence -> 0}, []}]                 |
# |[{document, 0, 12, 1 Les Granges, {sentence -> 0}, []}]                        |
# |[{document, 0, 12, 2 Les Granges, {sentence -> 0}, []}]                        |
# |[{document, 0, 13, 10 Les Granges, {sentence -> 0}, []}]                       |
# |[{document, 0, 36, 1082 Chemin de la Ferm de la Montagne, {sentence -> 0}, []}]|
# +-------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
result_1.select("token").show(n = 5, truncate = False)
# Out:
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |token                                                                                                                                                                                                                                                                                                                                                      |
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |[{token, 0, 0, 6, {sentence -> 0}, []}, {token, 2, 6, Place, {sentence -> 0}, []}, {token, 8, 9, du, {sentence -> 0}, []}, {token, 11, 14, Pese, {sentence -> 0}, []}, {token, 16, 19, Lait, {sentence -> 0}, []}]                                                                                                                                         |
# |[{token, 0, 0, 1, {sentence -> 0}, []}, {token, 2, 4, Les, {sentence -> 0}, []}, {token, 6, 12, Granges, {sentence -> 0}, []}]                                                                                                                                                                                                                             |
# |[{token, 0, 0, 2, {sentence -> 0}, []}, {token, 2, 4, Les, {sentence -> 0}, []}, {token, 6, 12, Granges, {sentence -> 0}, []}]                                                                                                                                                                                                                             |
# |[{token, 0, 1, 10, {sentence -> 0}, []}, {token, 3, 5, Les, {sentence -> 0}, []}, {token, 7, 13, Granges, {sentence -> 0}, []}]                                                                                                                                                                                                                            |
# |[{token, 0, 3, 1082, {sentence -> 0}, []}, {token, 5, 10, Chemin, {sentence -> 0}, []}, {token, 12, 13, de, {sentence -> 0}, []}, {token, 15, 16, la, {sentence -> 0}, []}, {token, 18, 21, Ferm, {sentence -> 0}, []}, {token, 23, 24, de, {sentence -> 0}, []}, {token, 26, 27, la, {sentence -> 0}, []}, {token, 29, 36, Montagne, {sentence -> 0}, []}]|
# +-----------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
result_1.select("document").printSchema()
# Out:
# root
#  |-- document: array (nullable = true)
#  |    |-- element: struct (containsNull = true)
#  |    |    |-- annotatorType: string (nullable = true)
#  |    |    |-- begin: integer (nullable = false)
#  |    |    |-- end: integer (nullable = false)
#  |    |    |-- result: string (nullable = true)
#  |    |    |-- metadata: map (nullable = true)
#  |    |    |    |-- key: string
#  |    |    |    |-- value: string (valueContainsNull = true)
#  |    |    |-- embeddings: array (nullable = true)
#  |    |    |    |-- element: float (containsNull = false)

# %% [markdown]
# # 2. Word Embedding

# %%
MODEL_NAME = "wikiner_840B_300"

# %%
if MODEL_NAME == "wikiner_840B_300":
    embeddings = WordEmbeddingsModel.pretrained('glove_840B_300', lang='xx') \
        .setInputCols(['document', 'token']) \
        .setOutputCol('embeddings')
elif MODEL_NAME == "wikiner_6B_300":
    embeddings = WordEmbeddingsModel.pretrained('glove_6B_300', lang='xx') \
        .setInputCols(['document', 'token']) \
        .setOutputCol('embeddings')
elif MODEL_NAME == "wikiner_6B_100":
    embeddings = WordEmbeddingsModel.pretrained('glove_100d') \
        .setInputCols(['document', 'token']) \
        .setOutputCol('embeddings')
# Out:
# glove_840B_300 download started this may take some time.
# Approximate size to download 2.3 GB
# [OK!]

# %%
pipeline_2 = Pipeline(stages=[
    embeddings
])
model_2 = pipeline_2.fit(empty_df)
result_2 = model_2.transform(result_1)

# %%
result_2.select("embeddings").show(n = 5, truncate = False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |embeddings                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                      ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# |[{word_embeddings, 0, 0, 6, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> 6, sentence -> 0}, [-0.41409, 0.4613, 0.1595, -0.13278, -0.04638, -0.31332, -0.22433, -0.049539, 0.58304, 0.55215, -0.12956, 0.3235, -0.37503, 0.1161, -0.54086, -0.074195, -0.18433, 1.8057, -0.29424, -0.077535, -0.10651, 0.084631, -0.1991, 0.16744, -0.056921, -0.28537, -0.20714, -0.039219, 0.34963, 0.079438, 0.0099502, 0.34987, -0.0080611, -0.074837, 0.35128, -0.10772, 0.079516, -0.083395, -0.043375, 0.12732, 0.18704, -0.39064, 0.16989, 0.012621, 0.13794, 0.29654, -0.17647, 0.21027, -0.037397, -0.17939, 0.011649, -0.011717, 0.033053, -0.41358, -0.11695, 0.67946, -0.0053384, 0.73829, 0.27088, 0.46958, 0.27046, -0.21254, 0.15404, 0.055291, -0.55955, -0.65174, 0.13874, 0.32813, -0.31222, 0.14469, 0.32915, 0.039365, 0.45022, 0.027096, 0.076306, 0.056508, 0.20632, 0.033492, 0.10329, 0.17778, 0.22365, 
0.13065, -0.10368, -0.0035233, 0.17343, -0.18197, 0.65326, 0.23019, -0.45648, -0.43991, -0.6002, -0.16156, 0.68317, 0.12706, 0.21021, 0.05954, 0.1143, 0.071461, -0.18991, 0.18602, -0.22569, -0.075579, 0.26753, 0.23241, 0.33782, -0.013335, -0.27759, -0.28046, 0.35744, 0.28508, -0.020296, -0.56703, -0.61217, -0.24736, 0.07503, -0.20949, 0.063145, -0.21524, 0.15349, -0.68363, 0.069773, -0.029956, 0.042111, 0.35376, 0.26438, -0.47369, 0.087441, -0.1727, -0.57266, 0.65335, 0.2982, 0.21146, 0.072774, -0.40614, 0.44499, 0.40681, -0.38182, 0.14123, -0.14834, -0.086844, 0.088162, -0.091581, -0.22962, -0.59926, -0.17848, 0.12163, -0.17667, 0.10561, 0.026478, -0.29526, 0.32065, 0.34479, -0.45062, -0.32088, -0.071298, 0.54001, 0.25588, -0.55751, -0.24802, 0.2135, -0.60393, 0.02165, -0.65082, -0.10526, 0.2935, -0.10018, -0.14407, 0.20123, 0.24051, -0.0086542, -0.39177, -0.47736, 0.37666, 0.8611, 0.32591, -0.37245, 0.18017, 0.1184, 0.0096263, -0.056887, -0.30986, -0.51214, 0.69266, 0.57278, 0.26934, -0.25183, 0.16946, 0.058859, 0.16396, 0.19134, -0.21759, 0.1487]}, {word_embeddings, 5, 10, Chemin, {isOOV -> false, pieceId -> -1, isWordStart -> true, token -> Chemin, sentence -> 0}, [0.26173, -0.24993, -0.99647, -0.77222, 0.57279, 0.5302, -0.16944, 0.10928, -0.059855, -0.56677, -0.060492, 0.62336, 0.47163, -0.40451, 0.6569, 0.13238, -0.53411, -0.73112, 0.062422, -0.025537, 0.33573, -0.15586, 0.16881, 0.31174, 0.98883, 0.092433, 0.37699, 0.10429, -0.30915, 0.53068, 0.54203, 0.1712, 0.69199, -0.51273, -0.28631, 0.04267, -0.2866, -0.066608, -0.16334, -0.13412, -0.059608, 0.099751, -0.058898, -0.49029, 0.080287, -0.25774, 0.42794, -0.16165, -0.32154, 0.4699, -0.19204, 0.29513, 0.35461, -0.072734, 0.40777, 0.52524, 0.34961, -0.17433, 0.22374, -0.031262, -0.16516, 0.078687, -0.094435, 0.4852, -0.40273, 0.87843, -0.24424, 0.19806, 0.58614, 0.12092, 0.18557, 0.21641, 0.25518, 0.57924, -0.37637, -0.49131, 1.2476, -0.23697, 0.31954, -0.0058669, -0.049784, -1.1873, -0.0091101, 0.17871, 0.42633, 0.50023, 0.068123, -0.24371, -0.45289, -0.12543, 0.30021,  ...
# +--------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------- ...
# only showing top 5 rows

# %% [markdown]
# # 3. NER model

# %%
ner_model = NerDLModel.pretrained(MODEL_NAME, 'fr') \
    .setInputCols(['document', 'token', 'embeddings']) \
    .setOutputCol('ner')

ner_converter = NerConverter() \
    .setInputCols(['document', 'token', 'ner']) \
    .setOutputCol('ner_chunk')
# Out:
# wikiner_840B_300 download started this may take some time.
# Approximate size to download 14.4 MB
# [OK!]

# %%
nlp_pipeline = Pipeline(stages=[
    ner_model,
    ner_converter
])
model = nlp_pipeline.fit(empty_df)
result = model.transform(result_2)

# %%
result.select("text", "ner").show(n = 5, truncate = False)
# Out:
# +-------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |text                                 |ner                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    |
# +-------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |6 Place du Pese Lait                 |[{named_entity, 0, 0, O, {word -> 6, sentence -> 0}, []}, {named_entity, 2, 6, I-LOC, {word -> Place, sentence -> 0}, []}, {named_entity, 8, 9, O, {word -> du, sentence -> 0}, []}, {named_entity, 11, 14, I-LOC, {word -> Pese, sentence -> 0}, []}, {named_entity, 16, 19, I-LOC, {word -> Lait, sentence -> 0}, []}]                                                                                                                                                                                                               |
# |1 Les Granges                        |[{named_entity, 0, 0, O, {word -> 1, sentence -> 0}, []}, {named_entity, 2, 4, O, {word -> Les, sentence -> 0}, []}, {named_entity, 6, 12, I-LOC, {word -> Granges, sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                               |
# |2 Les Granges                        |[{named_entity, 0, 0, O, {word -> 2, sentence -> 0}, []}, {named_entity, 2, 4, O, {word -> Les, sentence -> 0}, []}, {named_entity, 6, 12, I-LOC, {word -> Granges, sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                               |
# |10 Les Granges                       |[{named_entity, 0, 1, O, {word -> 10, sentence -> 0}, []}, {named_entity, 3, 5, O, {word -> Les, sentence -> 0}, []}, {named_entity, 7, 13, I-LOC, {word -> Granges, sentence -> 0}, []}]                                                                                                                                                                                                                                                                                                                                              |
# |1082 Chemin de la Ferm de la Montagne|[{named_entity, 0, 3, O, {word -> 1082, sentence -> 0}, []}, {named_entity, 5, 10, I-LOC, {word -> Chemin, sentence -> 0}, []}, {named_entity, 12, 13, I-LOC, {word -> de, sentence -> 0}, []}, {named_entity, 15, 16, I-LOC, {word -> la, sentence -> 0}, []}, {named_entity, 18, 21, I-LOC, {word -> Ferm, sentence -> 0}, []}, {named_entity, 23, 24, I-LOC, {word -> de, sentence -> 0}, []}, {named_entity, 26, 27, I-LOC, {word -> la, sentence -> 0}, []}, {named_entity, 29, 36, I-LOC, {word -> Montagne, sentence -> 0}, []}]|
# +-------------------------------------+---------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
result.select("ner_chunk").show(n = 5, truncate = False)
# Out:
# +--------------------------------------------------------------------------------------------------------------------------------------------------+
# |ner_chunk                                                                                                                                         |
# +--------------------------------------------------------------------------------------------------------------------------------------------------+
# |[{chunk, 2, 6, Place, {entity -> LOC, sentence -> 0, chunk -> 0}, []}, {chunk, 11, 19, Pese Lait, {entity -> LOC, sentence -> 0, chunk -> 1}, []}]|
# |[{chunk, 6, 12, Granges, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |[{chunk, 6, 12, Granges, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |[{chunk, 7, 13, Granges, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |[{chunk, 5, 36, Chemin de la Ferm de la Montagne, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                |
# +--------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
result.select("ner_chunk.result", "ner_chunk.metadata").show(n = 5, truncate = False)
# Out:
# +----------------------------------+----------------------------------------------------------------------------------------+
# |result                            |metadata                                                                                |
# +----------------------------------+----------------------------------------------------------------------------------------+
# |[Place, Pese Lait]                |[{entity -> LOC, sentence -> 0, chunk -> 0}, {entity -> LOC, sentence -> 0, chunk -> 1}]|
# |[Granges]                         |[{entity -> LOC, sentence -> 0, chunk -> 0}]                                            |
# |[Granges]                         |[{entity -> LOC, sentence -> 0, chunk -> 0}]                                            |
# |[Granges]                         |[{entity -> LOC, sentence -> 0, chunk -> 0}]                                            |
# |[Chemin de la Ferm de la Montagne]|[{entity -> LOC, sentence -> 0, chunk -> 0}]                                            |
# +----------------------------------+----------------------------------------------------------------------------------------+
# only showing top 5 rows

# %%
test = result.select(F.col("text"), F.col("ner_chunk.result").alias("result"), F.explode("ner_chunk.metadata"))
test.show(n = 20, truncate = False)
# Out:
# +-------------------------------------+---------------------------------------+-------------------------------------------+
# |text                                 |result                                 |col                                        |
# +-------------------------------------+---------------------------------------+-------------------------------------------+
# |6 Place du Pese Lait                 |[Place, Pese Lait]                     |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |6 Place du Pese Lait                 |[Place, Pese Lait]                     |{entity -> LOC, sentence -> 0, chunk -> 1} |
# |1 Les Granges                        |[Granges]                              |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |2 Les Granges                        |[Granges]                              |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |10 Les Granges                       |[Granges]                              |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |1082 Chemin de la Ferm de la Montagne|[Chemin de la Ferm de la Montagne]     |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |1083 Chemin de la Ferm de la Montagne|[1083 Chemin de la Ferm de la Montagne]|{entity -> LOC, sentence -> 0, chunk -> 0} |
# |291 La Forêt                         |[La Forêt]                             |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |844 Sous Terrea                      |[Terrea]                               |{entity -> PER, sentence -> 0, chunk -> 0} |
# |1405 Dalivoy                         |[Dalivoy]                              |{entity -> PER, sentence -> 0, chunk -> 0} |
# |1423 Dalivoy                         |[Dalivoy]                              |{entity -> PER, sentence -> 0, chunk -> 0} |
# |1082 Aux Traverses                   |[1082 Aux Traverses]                   |{entity -> MISC, sentence -> 0, chunk -> 0}|
# |1083 Aux Traverses                   |[Aux Traverses]                        |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |270 La Cordiere                      |[La Cordiere]                          |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |804 Preillon                         |[Preillon]                             |{entity -> PER, sentence -> 0, chunk -> 0} |
# |16 Montee de la Foret                |[16 Montee de la Foret]                |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |22 Montee de la Foret                |[22 Montee de la Foret]                |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |26 Montee de la Foret                |[26 Montee de la Foret]                |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |30 Montee de la Foret                |[30 Montee de la Foret]                |{entity -> LOC, sentence -> 0, chunk -> 0} |
# |37 Montee de la Foret                |[Montee de la Foret]                   |{entity -> PER, sentence -> 0, chunk -> 0} |
# +-------------------------------------+---------------------------------------+-------------------------------------------+
# only showing top 20 rows

# %%
test_2 = test.select("text", "result", "col.entity")
test_2.orderBy("text").show(n = 20, truncate = False)
# Out:
# +----------------------------+-------------------------+------+
# |text                        |result                   |entity|
# +----------------------------+-------------------------+------+
# |1 Impasse des Rosiers       |[1 Impasse des Rosiers]  |MISC  |
# |1 Le Clos des Charmilles    |[Clos des Charmilles]    |LOC   |
# |1 Les Granges               |[Granges]                |LOC   |
# |1 Lieu Dit les Bruyeres     |[1 Lieu Dit les Bruyeres]|MISC  |
# |1 Lot les Jardins D Agathe  |[1 Lot, Jardins D Agathe]|LOC   |
# |1 Lot les Jardins D Agathe  |[1 Lot, Jardins D Agathe]|LOC   |
# |1 Lotissement les Amandiers |[Amandiers]              |MISC  |
# |1 Place de la Mairie        |[1 Place, Mairie]        |LOC   |
# |1 Place de la Mairie        |[1 Place, Mairie]        |LOC   |
# |1 Route de Rance            |[1 Route de Rance]       |LOC   |
# |1 Route du Mont             |[1 Route du Mont]        |LOC   |
# |1 Rue Dangeville            |[1 Rue Dangeville]       |LOC   |
# |10 Chemin Louis Lumiere     |[10 Chemin Louis Lumiere]|MISC  |
# |10 Chemin des Vermots       |[10 Chemin des Vermots]  |MISC  |
# |10 Impasse Moreau           |[10 Impasse Moreau]      |MISC  |
# |10 Le Bourg                 |[Bourg]                  |LOC   |
# |10 Les Granges              |[Granges]                |LOC   |
# |10 Lotissement les Amandiers|[Amandiers]              |MISC  |
# |10 Ruelle des Vignerons     |[10 Ruelle des Vignerons]|LOC   |
# |100 Impasse Bellevue        |[Impasse Bellevue]       |LOC   |
# +----------------------------+-------------------------+------+
# only showing top 20 rows

# %%
test_3 = test_2.groupby("text", "entity").agg(F.count("entity").alias("count")).orderBy("text")
test_3.show(n = 20, truncate = False)
# Out:
# +----------------------------+------+-----+
# |text                        |entity|count|
# +----------------------------+------+-----+
# |1 Impasse des Rosiers       |MISC  |1    |
# |1 Le Clos des Charmilles    |LOC   |1    |
# |1 Les Granges               |LOC   |1    |
# |1 Lieu Dit les Bruyeres     |MISC  |1    |
# |1 Lot les Jardins D Agathe  |LOC   |2    |
# |1 Lotissement les Amandiers |MISC  |1    |
# |1 Place de la Mairie        |LOC   |2    |
# |1 Route de Rance            |LOC   |1    |
# |1 Route du Mont             |LOC   |1    |
# |1 Rue Dangeville            |LOC   |1    |
# |10 Chemin Louis Lumiere     |MISC  |1    |
# |10 Chemin des Vermots       |MISC  |1    |
# |10 Impasse Moreau           |MISC  |1    |
# |10 Le Bourg                 |LOC   |1    |
# |10 Les Granges              |LOC   |1    |
# |10 Lotissement les Amandiers|MISC  |1    |
# |10 Ruelle des Vignerons     |LOC   |1    |
# |100 Impasse Bellevue        |LOC   |1    |
# |100 Rue Dangeville          |PER   |2    |
# |1000 Le Buisson             |MISC  |1    |
# +----------------------------+------+-----+
# only showing top 20 rows

# %%
w2 = Window.partitionBy("text").orderBy(F.col("count").desc())

test_4 = test_3.withColumn("row", F.row_number().over(w2)) \
                .filter(F.col("row") == 1) \
                .drop("row").orderBy("text") \
                .groupby("entity").count(). \
                orderBy(F.col("count").desc())

test_4.show(n = 20, truncate = False)
# Out:
# +------+-----+
# |entity|count|
# +------+-----+
# |LOC   |620  |
# |MISC  |322  |
# |PER   |35   |
# |ORG   |1    |
# +------+-----+
