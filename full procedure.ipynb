# %%
import pandas as pd
import pyspark.sql.functions as F
from pyspark.sql.window import Window
from sparknlp.annotator import *
from sparknlp.base import *
from pyspark.sql.types import StringType
import sparknlp
from sparknlp.pretrained import PretrainedPipeline
from spacy.lang.fr.stop_words import STOP_WORDS as fr_stop

spark = sparknlp.start()

# %%
pipeline = PretrainedPipeline.from_disk('entity_recognizer_lg_fr')

# %%
'''
list_device = ["iPhone", "Apple watch", "macbook pro", "iPhone's"]
list_nom = ["Pierre", "Romain", "Pierre", "Dung", "Luc", "Simon", "Gru", "Nicolas"]

list_device_name = []
for device in list_device:
        for nom in list_nom:
            list_device_name.append(device + " " + nom)
            list_device_name.append(device + " De " + nom)
            list_device_name.append(device + " de " + nom)
            list_device_name.append(device + " d'" + nom)
'''

# %%
list_device_name = ["Iphone", "Iphone de Julien", "Iphone X", "Iphone De Nicolas", "Iphone's Antoine", \
                    "Apple Watch De Pierre", "Iphone de Romain", "Apple Watch de Pierre", "Iphone De Damien", "Iphone", \
                    "Doom 8", "Iphone Luc", "Iphone old", "Macbook Pro de Alex", "Apple Watch's Simon", \
                    "Macbook Pro d'Alex", "Iphone De Clément", "Iphone De Gru", "Machin", "Iphone 6 Fafa"]

# %%
path = "data/data_set_final.csv"
df = spark.read.option("header","true").csv(path)

# %%
pd_df = pd.DataFrame()
pd_df["device"] = list_device_name
df_device = spark.createDataFrame(pd_df)

# %%
def is_unstructured(df, col):
    letter_avg = df.agg(F.mean(F.length(F.regexp_replace(F.col(col), '[^a-zA-Z]', "")))).collect()[0][0]
    word_avg = df.agg(F.mean(F.size(F.split(F.col(col), " ")))).collect()[0][0]
    return letter_avg >= 1.0 and word_avg > 1.0

# %%
def get_entity(df, column):
    data = df.select(column).toDF("text")
    annotations = pipeline.transform(data)
        
    result = annotations.withColumn("id", F.monotonically_increasing_id()).select("id", "text", "entities")
    result = result.select(F.col("id"), F.col("text"), F.col("entities.result").alias("result"), F.explode("entities.metadata"))
    result = result.select("id", "text", "result", F.col("col.entity").alias("predict"))
    result = result.groupby("id", "predict").agg(F.count("predict").alias("count"))

    w = Window.partitionBy("id").orderBy(F.col("count").desc())

    result = result.withColumn("row", F.row_number().over(w)) \
                        .filter(F.col("row") == 1) \
                        .drop("row", "count") \
                        .groupby("predict").count()
        
    result = result.toPandas()
        
    other_row = {'predict': 'OTHER', 'count': annotations.count() - sum(result.loc[result.predict != 'MISC']['count'])}
    result = result.append(other_row, ignore_index = True)
    result.drop(result[result.predict == 'MISC'].index, inplace = True)
    result.sort_values(by = ['count'], ascending = False, inplace = True)
    
    return result

# %%
def update_text(text):
    result = []
    for t in text.lower().split(" "):
        if t not in fr_stop:
            result.append(t.capitalize())
        else:
            result.append(t)
    return " ".join(result)

my_udf = F.udf(lambda x: update_text(x), StringType())

# %%
def run(df):
    for col in df.columns:
        if is_unstructured(df, col): 
            df = df.withColumn(col, my_udf(F.col(col)))
        print("############## " + col + " ##############")
        print(get_entity(df, col))

# %%
run(df)
# Out:
# ############## type_de_carte ##############
#   predict  count
# 0     ORG  29899
# 2   OTHER  10097
# ############## numero_de_carte ##############
#   predict  count
# 1   OTHER  39996
# ############## iban ##############
#   predict  count
# 2     LOC  23626
# 4   OTHER  15295
# 0     ORG    757
# 1     PER    318
# ############## prenom ##############
#   predict  count
# 1     PER  29426
# 2     LOC   5325
# 4   OTHER   4419
# 0     ORG    826
# ############## nom ##############
#   predict  count
# 1     PER  29587
# 2     LOC   6288
# 4   OTHER   3337
# 0     ORG    784
# ############## tel ##############
#   predict  count
# 2   OTHER  39990
# 0     LOC      6
# ############## email ##############
#   predict  count
# 4   OTHER  25153
# 1     PER   8103
# 2     LOC   3814
# 0     ORG   2926
# ############## date ##############
#   predict  count
# 0   OTHER  39996
# ############## adresse ##############
#   predict  count
# 2     LOC  31256
# 4   OTHER   6232
# 1     PER   1935
# 0     ORG    573

# %%
df_device = df_device.withColumn("device_updated", my_udf(F.col("device")))

# %%
annotations = pipeline.transform(df_device.select("device").toDF("text"))
result = annotations.select(F.col("text"), F.col("ner.result").alias("ner"), F.col("entities.result").alias("text ner_chunk"), F.col("entities.metadata").alias("ner_chunk"))
result.show(n = 200, truncate = False)
# Out:
# +---------------------+----------------------------+-----------------------+-----------------------------------------------------------------------------------------+
# |text                 |ner                         |text ner_chunk         |ner_chunk                                                                                |
# +---------------------+----------------------------+-----------------------+-----------------------------------------------------------------------------------------+
# |Iphone               |[I-MISC]                    |[Iphone]               |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone de Julien     |[I-MISC, O, I-PER]          |[Iphone, Julien]       |[{entity -> MISC, sentence -> 0, chunk -> 0}, {entity -> PER, sentence -> 0, chunk -> 1}]|
# |Iphone X             |[I-MISC, I-MISC]            |[Iphone X]             |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone De Nicolas    |[I-MISC, I-MISC, I-MISC]    |[Iphone De Nicolas]    |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone's Antoine     |[I-LOC, I-PER]              |[Iphone's Antoine]     |[{entity -> LOC, sentence -> 0, chunk -> 0}]                                             |
# |Apple Watch De Pierre|[I-ORG, I-ORG, I-ORG, I-ORG]|[Apple Watch De Pierre]|[{entity -> ORG, sentence -> 0, chunk -> 0}]                                             |
# |Iphone de Romain     |[O, O, I-PER]               |[Romain]               |[{entity -> PER, sentence -> 0, chunk -> 0}]                                             |
# |Apple Watch de Pierre|[I-ORG, I-ORG, O, I-PER]    |[Apple Watch, Pierre]  |[{entity -> ORG, sentence -> 0, chunk -> 0}, {entity -> PER, sentence -> 0, chunk -> 1}] |
# |Iphone De Damien     |[I-MISC, I-MISC, I-MISC]    |[Iphone De Damien]     |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone               |[I-MISC]                    |[Iphone]               |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Doom 8               |[I-MISC, I-MISC]            |[Doom 8]               |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone Luc           |[I-MISC, I-MISC]            |[Iphone Luc]           |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone old           |[I-MISC, I-MISC]            |[Iphone old]           |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Macbook Pro de Alex  |[I-MISC, I-MISC, O, I-PER]  |[Macbook Pro, Alex]    |[{entity -> MISC, sentence -> 0, chunk -> 0}, {entity -> PER, sentence -> 0, chunk -> 1}]|
# |Apple Watch's Simon  |[I-ORG, I-ORG, I-ORG]       |[Apple Watch's Simon]  |[{entity -> ORG, sentence -> 0, chunk -> 0}]                                             |
# |Macbook Pro d'Alex   |[I-MISC, I-MISC, I-MISC]    |[Macbook Pro d'Alex]   |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone De Clément    |[I-MISC, I-MISC, I-MISC]    |[Iphone De Clément]    |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone De Gru        |[I-MISC, I-MISC, I-MISC]    |[Iphone De Gru]        |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Machin               |[I-PER]                     |[Machin]               |[{entity -> PER, sentence -> 0, chunk -> 0}]                                             |
# |Iphone 6 Fafa        |[I-MISC, I-MISC, I-MISC]    |[Iphone 6 Fafa]        |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# +---------------------+----------------------------+-----------------------+-----------------------------------------------------------------------------------------+

# %%
annotations = pipeline.transform(df_device.select("device_updated").toDF("text"))
result = annotations.select(F.col("text"), F.col("ner.result").alias("ner"), F.col("entities.result").alias("text ner_chunk"), F.col("entities.metadata").alias("ner_chunk"))
result.show(n = 200, truncate = False)
# Out:
# +---------------------+--------------------------+---------------------+-----------------------------------------------------------------------------------------+
# |text                 |ner                       |text ner_chunk       |ner_chunk                                                                                |
# +---------------------+--------------------------+---------------------+-----------------------------------------------------------------------------------------+
# |Iphone               |[I-MISC]                  |[Iphone]             |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone de Julien     |[I-MISC, O, I-PER]        |[Iphone, Julien]     |[{entity -> MISC, sentence -> 0, chunk -> 0}, {entity -> PER, sentence -> 0, chunk -> 1}]|
# |Iphone X             |[I-MISC, I-MISC]          |[Iphone X]           |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone de Nicolas    |[I-MISC, O, I-PER]        |[Iphone, Nicolas]    |[{entity -> MISC, sentence -> 0, chunk -> 0}, {entity -> PER, sentence -> 0, chunk -> 1}]|
# |Iphone's Antoine     |[I-LOC, I-PER]            |[Iphone's Antoine]   |[{entity -> LOC, sentence -> 0, chunk -> 0}]                                             |
# |Apple Watch de Pierre|[I-ORG, I-ORG, O, I-PER]  |[Apple Watch, Pierre]|[{entity -> ORG, sentence -> 0, chunk -> 0}, {entity -> PER, sentence -> 0, chunk -> 1}] |
# |Iphone de Romain     |[O, O, I-PER]             |[Romain]             |[{entity -> PER, sentence -> 0, chunk -> 0}]                                             |
# |Apple Watch de Pierre|[I-ORG, I-ORG, O, I-PER]  |[Apple Watch, Pierre]|[{entity -> ORG, sentence -> 0, chunk -> 0}, {entity -> PER, sentence -> 0, chunk -> 1}] |
# |Iphone de Damien     |[I-MISC, O, I-PER]        |[Iphone, Damien]     |[{entity -> MISC, sentence -> 0, chunk -> 0}, {entity -> PER, sentence -> 0, chunk -> 1}]|
# |Iphone               |[I-MISC]                  |[Iphone]             |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Doom 8               |[I-MISC, I-MISC]          |[Doom 8]             |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone Luc           |[I-MISC, I-MISC]          |[Iphone Luc]         |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone Old           |[I-MISC, I-MISC]          |[Iphone Old]         |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Macbook Pro de Alex  |[I-MISC, I-MISC, O, I-PER]|[Macbook Pro, Alex]  |[{entity -> MISC, sentence -> 0, chunk -> 0}, {entity -> PER, sentence -> 0, chunk -> 1}]|
# |Apple Watch's Simon  |[I-ORG, I-ORG, I-ORG]     |[Apple Watch's Simon]|[{entity -> ORG, sentence -> 0, chunk -> 0}]                                             |
# |Macbook Pro D'alex   |[I-MISC, I-MISC, I-MISC]  |[Macbook Pro D'alex] |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Iphone de Clément    |[O, O, I-PER]             |[Clément]            |[{entity -> PER, sentence -> 0, chunk -> 0}]                                             |
# |Iphone de Gru        |[I-MISC, I-MISC, I-MISC]  |[Iphone de Gru]      |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# |Machin               |[I-PER]                   |[Machin]             |[{entity -> PER, sentence -> 0, chunk -> 0}]                                             |
# |Iphone 6 Fafa        |[I-MISC, I-MISC, I-MISC]  |[Iphone 6 Fafa]      |[{entity -> MISC, sentence -> 0, chunk -> 0}]                                            |
# +---------------------+--------------------------+---------------------+-----------------------------------------------------------------------------------------+

# %%
annotations = pipeline.transform(df.select("adresse").toDF("text"))
result = annotations.withColumn("id", F.monotonically_increasing_id()).select("id", "text", "entities")
result = result.select(F.col("id"), F.col("text"), F.col("entities.result").alias("result"), F.explode("entities.metadata"))
#result = result.select("id", "text", "result", F.col("col.entity").alias("predict"))
result.show(n = 200, truncate = False)
# Out:
# +---+---------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |id |text                             |entities                                                                                                                                                      |
# +---+---------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# |0  |Route de Trevoux                 |[{chunk, 0, 15, Route de Trevoux, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |1  |Rue Sainte Marie                 |[{chunk, 0, 15, Rue Sainte Marie, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |2  |1711 Route d’Hauteville          |[{chunk, 5, 22, Route d’Hauteville, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |3  |Route du Morbier                 |[{chunk, 0, 15, Route du Morbier, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |4  |Rue des Bleuets                  |[{chunk, 0, 14, Rue des Bleuets, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |5  |7 Rue Jean Monnet                |[{chunk, 0, 16, 7 Rue Jean Monnet, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                           |
# |6  |193 Chemin de Chavagneux         |[{chunk, 4, 23, Chemin de Chavagneux, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                        |
# |7  |55 Rue du Coteau                 |[{chunk, 0, 15, 55 Rue du Coteau, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |8  |Rue de l’Eglise                  |[{chunk, 0, 14, Rue de l’Eglise, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |9  |89 Impasse des Chênes            |[{chunk, 0, 20, 89 Impasse des Chênes, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                      |
# |10 |Rue du Journans                  |[{chunk, 0, 14, Rue du Journans, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |11 |Rue de la Rogeraie               |[{chunk, 0, 17, Rue de la Rogeraie, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |12 |3 Au Bourg                       |[{chunk, 5, 9, Bourg, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                        |
# |13 |12 Rue Jean Emery                |[{chunk, 0, 16, 12 Rue Jean Emery, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                           |
# |14 |Rue du Dauphiné                  |[{chunk, 7, 14, Dauphiné, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                    |
# |15 |162 Route de Bottenay            |[{chunk, 0, 20, 162 Route de Bottenay, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                       |
# |16 |Rue de la Doy                    |[{chunk, 0, 12, Rue de la Doy, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                               |
# |17 |Rue des Colonnes                 |[{chunk, 0, 15, Rue des Colonnes, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |18 |541 Route du Boissonnet          |[{chunk, 0, 22, 541 Route du Boissonnet, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                     |
# |19 |Route de Bourg                   |[{chunk, 0, 13, Route de Bourg, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |20 |Route de Saint Etienne du Bois   |[{chunk, 9, 29, Saint Etienne du Bois, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                       |
# |21 |Rue de la Tour                   |[{chunk, 0, 13, Rue de la Tour, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |22 |Rue de la Rogeraie               |[{chunk, 0, 17, Rue de la Rogeraie, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |23 |Chemin sous la Ville             |[{chunk, 15, 19, Ville, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                      |
# |24 |418 Chemin du Chataignier        |[{chunk, 0, 24, 418 Chemin du Chataignier, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                  |
# |25 |Impasse des Irantelles           |[{chunk, 12, 21, Irantelles, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                                |
# |26 |34 Impasse du Plat               |[{chunk, 0, 17, 34 Impasse du Plat, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |27 |Chemin Vionnet des Places        |[{chunk, 0, 13, Chemin Vionnet, {entity -> PER, sentence -> 0, chunk -> 0}, []}, {chunk, 19, 24, Places, {entity -> LOC, sentence -> 0, chunk -> 1}, []}]     |
# |28 |95 Rue des Ecoles                |[{chunk, 3, 16, Rue des Ecoles, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |29 |Rue des Morilles                 |[{chunk, 0, 15, Rue des Morilles, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |30 |5 Avenue des Tilleuls            |[{chunk, 0, 20, 5 Avenue des Tilleuls, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                       |
# |31 |961 Chemin de Corneloup          |[{chunk, 0, 22, 961 Chemin de Corneloup, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                     |
# |32 |408 Route de Lyon                |[{chunk, 0, 16, 408 Route de Lyon, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                           |
# |33 |Allee du Cubilot                 |[{chunk, 0, 15, Allee du Cubilot, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |34 |90 Chemin de la Fontaine         |[{chunk, 0, 23, 90 Chemin de la Fontaine, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                    |
# |35 |Rue Bombec                       |[{chunk, 0, 9, Rue Bombec, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                   |
# |36 |Lotissement Genevriers l’Europe  |[{chunk, 12, 30, Genevriers l’Europe, {entity -> PER, sentence -> 0, chunk -> 0}, []}]                                                                        |
# |37 |Chemin Levé                      |[{chunk, 0, 10, Chemin Levé, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                                |
# |38 |Rue de Cornier                   |[{chunk, 0, 13, Rue de Cornier, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |39 |424 Route de Marmont             |[{chunk, 4, 19, Route de Marmont, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |40 |Impasse des Irantelles           |[{chunk, 12, 21, Irantelles, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                                |
# |41 |La Rue                           |[{chunk, 3, 5, Rue, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                          |
# |42 |Route de la Boisse               |[{chunk, 12, 17, Boisse, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                     |
# |43 |Rue de la Lilette                |[{chunk, 0, 16, Rue de la Lilette, {entity -> PER, sentence -> 0, chunk -> 0}, []}]                                                                           |
# |44 |9 Lotissement du Janivon         |[{chunk, 17, 23, Janivon, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                    |
# |45 |30 Rue Principale                |[{chunk, 3, 16, Rue Principale, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |46 |143 Chemin des Liavins           |[{chunk, 0, 21, 143 Chemin des Liavins, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                     |
# |47 |410 Rue du Saugey                |[{chunk, 4, 16, Rue du Saugey, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                               |
# |48 |Rue du Chateau des Bains         |[{chunk, 0, 23, Rue du Chateau des Bains, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                    |
# |49 |Chemin Vie de Vaise              |[{chunk, 0, 18, Chemin Vie de Vaise, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                        |
# |50 |2 Rue des Barmettes              |[{chunk, 0, 18, 2 Rue des Barmettes, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                        |
# |51 |Grande Rue                       |[{chunk, 0, 9, Grande Rue, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                   |
# |52 |80 Grande Rue                    |[{chunk, 0, 12, 80 Grande Rue, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |53 |Grande Rue                       |[{chunk, 0, 9, Grande Rue, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                   |
# |54 |Rue de la Tour                   |[{chunk, 0, 13, Rue de la Tour, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |55 |Rue des Cèpes                    |[{chunk, 0, 12, Rue des Cèpes, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                               |
# |56 |Lotissement les Loups            |[{chunk, 16, 20, Loups, {entity -> ORG, sentence -> 0, chunk -> 0}, []}]                                                                                      |
# |57 |Au Dessus de la Roche            |[{chunk, 3, 20, Dessus de la Roche, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |58 |4 Route de Divonne               |[{chunk, 0, 17, 4 Route de Divonne, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |59 |Rue Principale Vaux Fevroux      |[{chunk, 0, 26, Rue Principale Vaux Fevroux, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                 |
# |60 |Rue du Dauphiné                  |[{chunk, 7, 14, Dauphiné, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                    |
# |61 |338 Rue du Village               |[{chunk, 4, 17, Rue du Village, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |62 |5 Rue de L Ecole                 |[{chunk, 2, 15, Rue de L Ecole, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |63 |Route des Dames                  |[{chunk, 0, 14, Route des Dames, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |64 |Route de Poncin                  |[{chunk, 9, 14, Poncin, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                      |
# |65 |3 Place Honore d’Urfe            |[{chunk, 0, 20, 3 Place Honore d’Urfe, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                       |
# |66 |81 Rue Traversière               |[{chunk, 0, 17, 81 Rue Traversière, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |67 |Grande Rue                       |[{chunk, 0, 9, Grande Rue, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                   |
# |68 |Chemin de Saint Michel           |[{chunk, 10, 21, Saint Michel, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                               |
# |69 |Rue des Grenodieres              |[{chunk, 0, 18, Rue des Grenodieres, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |70 |Rue Paul Blanc                   |[{chunk, 0, 13, Rue Paul Blanc, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |71 |2100 Chemin de Tanvol            |[{chunk, 0, 20, 2100 Chemin de Tanvol, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                      |
# |72 |175 Rue de l’Etang               |[{chunk, 4, 17, Rue de l’Etang, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |73 |22 Rue Aristide Briand           |[{chunk, 0, 21, 22 Rue Aristide Briand, {entity -> ORG, sentence -> 0, chunk -> 0}, []}]                                                                      |
# |74 |55 Impasse des Noisettes         |[{chunk, 0, 23, 55 Impasse des Noisettes, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                   |
# |75 |Route de Prou                    |[{chunk, 0, 12, Route de Prou, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                               |
# |76 |Chemin de la Charrière           |[{chunk, 13, 21, Charrière, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                  |
# |77 |Enceinte Buyaz                   |[{chunk, 9, 13, Buyaz, {entity -> PER, sentence -> 0, chunk -> 0}, []}]                                                                                       |
# |78 |Allée des Alouettes              |[{chunk, 0, 18, Allée des Alouettes, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |79 |Rue du Puits Mathieu             |[{chunk, 0, 19, Rue du Puits Mathieu, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                        |
# |80 |Lotissement Bois Joli            |[{chunk, 12, 15, Bois, {entity -> PER, sentence -> 0, chunk -> 0}, []}, {chunk, 17, 20, Joli, {entity -> PER, sentence -> 0, chunk -> 1}, []}]                |
# |81 |Route du Logis Neuf              |[{chunk, 9, 18, Logis Neuf, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                  |
# |82 |4 Impasse du Quart d’Amont       |[{chunk, 0, 25, 4 Impasse du Quart d’Amont, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                 |
# |83 |47 Rue du Vieux Quartier Latin   |[{chunk, 0, 5, 47 Rue, {entity -> LOC, sentence -> 0, chunk -> 0}, []}, {chunk, 10, 29, Vieux Quartier Latin, {entity -> LOC, sentence -> 0, chunk -> 1}, []}]|
# |84 |879 Chemin de l’Aigrefeuille     |[{chunk, 0, 27, 879 Chemin de l’Aigrefeuille, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                               |
# |85 |421 Voie du Tram                 |[{chunk, 4, 15, Voie du Tram, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                |
# |86 |34 Rue des Chaumes               |[{chunk, 0, 17, 34 Rue des Chaumes, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |87 |935 Chemin de la Cotiere         |[{chunk, 4, 23, Chemin de la Cotiere, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                        |
# |88 |Montee de l’Orme                 |[{chunk, 0, 15, Montee de l’Orme, {entity -> PER, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |89 |2 Place du Champ de Mars         |[{chunk, 0, 23, 2 Place du Champ de Mars, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                    |
# |90 |Rue Centrale                     |[{chunk, 0, 11, Rue Centrale, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                |
# |91 |41 Rue des Genetes               |[{chunk, 0, 17, 41 Rue des Genetes, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |92 |Rue du Port                      |[{chunk, 0, 10, Rue du Port, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                 |
# |93 |276 Allee de la Geliere          |[{chunk, 4, 22, Allee de la Geliere, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |94 |5 Janivon                        |[{chunk, 2, 8, Janivon, {entity -> PER, sentence -> 0, chunk -> 0}, []}]                                                                                      |
# |95 |913 Chemin de l’Aigrefeuille     |[{chunk, 0, 27, 913 Chemin de l’Aigrefeuille, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                |
# |96 |19 Avenue du Général de Gaulle   |[{chunk, 0, 29, 19 Avenue du Général de Gaulle, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                              |
# |97 |1020 Rue de Majornas             |[{chunk, 5, 19, Rue de Majornas, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |98 |1035 Route de la Dombes          |[{chunk, 0, 22, 1035 Route de la Dombes, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                     |
# |99 |Rue Joli Bugey                   |[{chunk, 0, 13, Rue Joli Bugey, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |100|274 Route de la Corias           |[{chunk, 4, 21, Route de la Corias, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |101|Rue de l’Artisanat               |[{chunk, 0, 17, Rue de l’Artisanat, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |102|80 Rue Amédée Bonnet             |[{chunk, 3, 19, Rue Amédée Bonnet, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                           |
# |103|Route des Echets                 |[{chunk, 0, 15, Route des Echets, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |104|Lotissement les Thiars           |[{chunk, 16, 21, Thiars, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                                    |
# |105|Rue de Fenières                  |[{chunk, 0, 14, Rue de Fenières, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |106|980 Che d’Agnereins              |[{chunk, 4, 6, Che, {entity -> PER, sentence -> 0, chunk -> 0}, []}]                                                                                          |
# |107|80 Montée du Four                |[{chunk, 0, 16, 80 Montée du Four, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |108|Route de Trevoux                 |[{chunk, 0, 15, Route de Trevoux, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |109|Chemin de la Fin                 |[{chunk, 0, 15, Chemin de la Fin, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |110|346 Route du Boissonnet          |[{chunk, 0, 22, 346 Route du Boissonnet, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                     |
# |111|60 Rue Alexandre Bérard          |[{chunk, 0, 22, 60 Rue Alexandre Bérard, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                     |
# |112|12 Rue Antoine Buy               |[{chunk, 0, 17, 12 Rue Antoine Buy, {entity -> ORG, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |113|Rue du Tilleul                   |[{chunk, 0, 13, Rue du Tilleul, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |114|Lotissement le Picardet          |[{chunk, 15, 22, Picardet, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                                  |
# |115|109 Montée des Cannes            |[{chunk, 0, 20, 109 Montée des Cannes, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                      |
# |116|Chemin de Grammon                |[{chunk, 0, 16, Chemin de Grammon, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |117|60 Lotissement de la Croix Trieux|[{chunk, 3, 13, Lotissement, {entity -> LOC, sentence -> 0, chunk -> 0}, []}, {chunk, 21, 32, Croix Trieux, {entity -> LOC, sentence -> 0, chunk -> 1}, []}]  |
# |118|Grande Rue                       |[{chunk, 0, 9, Grande Rue, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                   |
# |119|Rue des Rouges-Gorges            |[{chunk, 0, 20, Rue des Rouges-Gorges, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                       |
# |120|3 Chemin de la Dame Louise       |[{chunk, 0, 25, 3 Chemin de la Dame Louise, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                 |
# |121|6 Rocade des Carrés              |[{chunk, 0, 7, 6 Rocade, {entity -> LOC, sentence -> 0, chunk -> 0}, []}, {chunk, 13, 18, Carrés, {entity -> LOC, sentence -> 0, chunk -> 1}, []}]            |
# |122|40 Rue Aristide Briand           |[{chunk, 0, 21, 40 Rue Aristide Briand, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                      |
# |123|Rue des Champs Fleuris           |[{chunk, 0, 2, Rue, {entity -> LOC, sentence -> 0, chunk -> 0}, []}, {chunk, 8, 21, Champs Fleuris, {entity -> LOC, sentence -> 0, chunk -> 1}, []}]          |
# |124|Chemin de Gaz de Banc            |[{chunk, 10, 20, Gaz de Banc, {entity -> ORG, sentence -> 0, chunk -> 0}, []}]                                                                                |
# |125|Rue des Dentines                 |[{chunk, 0, 15, Rue des Dentines, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |126|19 Lotissement En Marmoerain     |[{chunk, 3, 27, Lotissement En Marmoerain, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                  |
# |127|140 Chemin du Mont Riant         |[{chunk, 14, 23, Mont Riant, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                 |
# |128|Impasse du Colomier              |[{chunk, 11, 18, Colomier, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                   |
# |129|Rue des Noyers                   |[{chunk, 0, 13, Rue des Noyers, {entity -> PER, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |130|836 Route d’Hauteville           |[{chunk, 4, 21, Route d’Hauteville, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |131|Lotissement Clos des Bouviers I  |[{chunk, 0, 30, Lotissement Clos des Bouviers I, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                            |
# |132|Fay                              |[{chunk, 0, 2, Fay, {entity -> PER, sentence -> 0, chunk -> 0}, []}]                                                                                          |
# |133|37 Lotissement le Clos des Frênes|[{chunk, 18, 32, Clos des Frênes, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |134|189 Rue du Prémonin              |[{chunk, 4, 18, Rue du Prémonin, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |135|Rue de la Cigogne                |[{chunk, 0, 16, Rue de la Cigogne, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                           |
# |136|15 Rue Alexandre Bérard          |[{chunk, 0, 22, 15 Rue Alexandre Bérard, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                     |
# |137|Grande Rue                       |[{chunk, 0, 9, Grande Rue, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                   |
# |138|21 Rue de la Fruitière           |[{chunk, 0, 21, 21 Rue de la Fruitière, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                      |
# |139|Quai du Buizin                   |[{chunk, 8, 13, Buizin, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                      |
# |140|17 Rue Henri Dunant              |[{chunk, 0, 18, 17 Rue Henri Dunant, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |141|Boulevard des Combattants        |[{chunk, 0, 24, Boulevard des Combattants, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                   |
# |142|128 Rue Louis Lepine             |[{chunk, 4, 19, Rue Louis Lepine, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |143|9 Genevriers le Petit Verger     |[{chunk, 0, 11, 9 Genevriers, {entity -> LOC, sentence -> 0, chunk -> 0}, []}, {chunk, 16, 27, Petit Verger, {entity -> LOC, sentence -> 0, chunk -> 1}, []}] |
# |144|12 Lotissement En Marmoerain     |[{chunk, 0, 27, 12 Lotissement En Marmoerain, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                               |
# |145|142 Allée de la Panissette       |[{chunk, 0, 25, 142 Allée de la Panissette, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                 |
# |146|Rue Neuve                        |[{chunk, 0, 8, Rue Neuve, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                    |
# |147|Chemin de l’Ouche                |[{chunk, 10, 16, l’Ouche, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                    |
# |148|Saint-Lazare                     |[{chunk, 0, 11, Saint-Lazare, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                |
# |149|Rue de Fenières                  |[{chunk, 0, 14, Rue de Fenières, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |150|4 Lot les Jardins D Agathe       |[{chunk, 0, 4, 4 Lot, {entity -> LOC, sentence -> 0, chunk -> 0}, []}, {chunk, 10, 25, Jardins D Agathe, {entity -> LOC, sentence -> 0, chunk -> 1}, []}]     |
# |151|Chemin du Vezely                 |[{chunk, 10, 15, Vezely, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                     |
# |152|29 Rue Henri Dunant              |[{chunk, 0, 18, 29 Rue Henri Dunant, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |153|126 Chemin des Gremelieres       |[{chunk, 15, 25, Gremelieres, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                |
# |154|Chemin des Bourdonnieres         |[{chunk, 11, 23, Bourdonnieres, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |155|Rue des Sources                  |[{chunk, 0, 14, Rue des Sources, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |156|Rue des Rossignols               |[{chunk, 0, 17, Rue des Rossignols, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |157|Rue Pre de Fontaine              |[{chunk, 0, 6, Rue Pre, {entity -> MISC, sentence -> 0, chunk -> 0}, []}, {chunk, 11, 18, Fontaine, {entity -> PER, sentence -> 0, chunk -> 1}, []}]          |
# |158|223 Rue Alexandre Bérard         |[{chunk, 0, 23, 223 Rue Alexandre Bérard, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                    |
# |159|Rue des Renardes                 |[{chunk, 0, 15, Rue des Renardes, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |160|78 Chemin du Pré de la Ville     |[{chunk, 0, 27, 78 Chemin du Pré de la Ville, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                |
# |161|35 Rue des Mouettes              |[{chunk, 0, 18, 35 Rue des Mouettes, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |162|155 Chemin des Cadalles          |[{chunk, 0, 22, 155 Chemin des Cadalles, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                    |
# |163|43 Rue Georges Guynemer          |[{chunk, 0, 22, 43 Rue Georges Guynemer, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                     |
# |164|191 Rue du Tiret                 |[{chunk, 4, 15, Rue du Tiret, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                |
# |165|83 Chemin de la Grange Neuve     |[{chunk, 0, 8, 83 Chemin, {entity -> LOC, sentence -> 0, chunk -> 0}, []}, {chunk, 16, 27, Grange Neuve, {entity -> LOC, sentence -> 0, chunk -> 1}, []}]     |
# |166|58 Chemin du Hameau              |[{chunk, 0, 18, 58 Chemin du Hameau, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |167|90 Montée des Cannes             |[{chunk, 0, 19, 90 Montée des Cannes, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                       |
# |168|56 Allee de l’Etrac              |[{chunk, 3, 18, Allee de l’Etrac, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |169|Rue de Buffières                 |[{chunk, 0, 15, Rue de Buffières, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |170|92 Route de Bourg                |[{chunk, 0, 16, 92 Route de Bourg, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                           |
# |171|Chemin de la Pralet              |[{chunk, 13, 18, Pralet, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                     |
# |172|Impasse du Capite                |[{chunk, 11, 16, Capite, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                     |
# |173|41 Chemin En Martel              |[{chunk, 10, 18, En Martel, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                                 |
# |174|560 Rue Royale                   |[{chunk, 4, 13, Rue Royale, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                  |
# |175|Route de Grand Corent            |[{chunk, 9, 20, Grand Corent, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                |
# |176|Le Clos des Dombes               |[{chunk, 3, 17, Clos des Dombes, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |177|14 Allee Andre Charles Boulle    |[{chunk, 0, 28, 14 Allee Andre Charles Boulle, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                              |
# |178|86 Rue du Molaret                |[{chunk, 3, 16, Rue du Molaret, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |179|278 Route de Saint Trivier       |[{chunk, 4, 25, Route de Saint Trivier, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                      |
# |180|Grande Rue                       |[{chunk, 0, 9, Grande Rue, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                   |
# |181|179 Route de Laval               |[{chunk, 0, 17, 179 Route de Laval, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# |182|Chemin du Vallon des Planches    |[{chunk, 10, 28, Vallon des Planches, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                        |
# |183|Rue des Mesanges                 |[{chunk, 0, 15, Rue des Mesanges, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |184|Rue Neuve                        |[{chunk, 0, 8, Rue Neuve, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                    |
# |185|223 Rue des Brotteaux            |[{chunk, 0, 20, 223 Rue des Brotteaux, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                       |
# |186|3 Avenue de Verdun               |[{chunk, 0, 17, 3 Avenue de Verdun, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                         |
# |187|10 Rue Bellievre                 |[{chunk, 0, 15, 10 Rue Bellievre, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                            |
# |188|La Creuz                         |[{chunk, 3, 7, Creuz, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                        |
# |189|Impasse des Magnolias            |[{chunk, 12, 20, Magnolias, {entity -> MISC, sentence -> 0, chunk -> 0}, []}]                                                                                 |
# |190|Route de Sainte Olive            |[{chunk, 9, 20, Sainte Olive, {entity -> PER, sentence -> 0, chunk -> 0}, []}]                                                                                |
# |191|Allée du Pré Vert                |[{chunk, 9, 16, Pré Vert, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                    |
# |192|58 Rue Aristide Briand           |[{chunk, 0, 21, 58 Rue Aristide Briand, {entity -> ORG, sentence -> 0, chunk -> 0}, []}]                                                                      |
# |193|8 Allee du Buidon                |[{chunk, 0, 16, 8 Allee du Buidon, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                           |
# |194|162 Rue du Château               |[{chunk, 4, 17, Rue du Château, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                              |
# |195|Rue Neuve                        |[{chunk, 0, 8, Rue Neuve, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                                    |
# |196|Rue du Besson                    |[{chunk, 0, 12, Rue du Besson, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                               |
# |197|Rue des Battieres                |[{chunk, 0, 16, Rue des Battieres, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                           |
# |198|Allee des Rubis                  |[{chunk, 0, 14, Allee des Rubis, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                             |
# |199|Rue de la Doraille               |[{chunk, 0, 17, Rue de la Doraille, {entity -> LOC, sentence -> 0, chunk -> 0}, []}]                                                                          |
# +---+---------------------------------+--------------------------------------------------------------------------------------------------------------------------------------------------------------+
# only showing top 200 rows

# %%
annotations = pipeline.transform(df.select("adresse").toDF("text"))
result = annotations.withColumn("id", F.monotonically_increasing_id()).select("id", "text", "entities")
result = result.select(F.col("id"), F.col("text"), F.col("entities.result").alias("result"), F.explode("entities.metadata"))
result = result.select("id", "text", "result", F.col("col.entity").alias("predict"))
result.show(n = 200, truncate = False)
# Out:
# +---+---------------------------------+---------------------------------+-------+
# |id |text                             |result                           |predict|
# +---+---------------------------------+---------------------------------+-------+
# |0  |Route de Trevoux                 |[Route de Trevoux]               |LOC    |
# |1  |Rue Sainte Marie                 |[Rue Sainte Marie]               |LOC    |
# |2  |1711 Route d’Hauteville          |[Route d’Hauteville]             |LOC    |
# |3  |Route du Morbier                 |[Route du Morbier]               |LOC    |
# |4  |Rue des Bleuets                  |[Rue des Bleuets]                |LOC    |
# |5  |7 Rue Jean Monnet                |[7 Rue Jean Monnet]              |LOC    |
# |6  |193 Chemin de Chavagneux         |[Chemin de Chavagneux]           |LOC    |
# |7  |55 Rue du Coteau                 |[55 Rue du Coteau]               |LOC    |
# |8  |Rue de l’Eglise                  |[Rue de l’Eglise]                |LOC    |
# |9  |89 Impasse des Chênes            |[89 Impasse des Chênes]          |MISC   |
# |10 |Rue du Journans                  |[Rue du Journans]                |LOC    |
# |11 |Rue de la Rogeraie               |[Rue de la Rogeraie]             |LOC    |
# |12 |3 Au Bourg                       |[Bourg]                          |LOC    |
# |13 |12 Rue Jean Emery                |[12 Rue Jean Emery]              |LOC    |
# |14 |Rue du Dauphiné                  |[Dauphiné]                       |LOC    |
# |15 |162 Route de Bottenay            |[162 Route de Bottenay]          |LOC    |
# |16 |Rue de la Doy                    |[Rue de la Doy]                  |LOC    |
# |17 |Rue des Colonnes                 |[Rue des Colonnes]               |LOC    |
# |18 |541 Route du Boissonnet          |[541 Route du Boissonnet]        |LOC    |
# |19 |Route de Bourg                   |[Route de Bourg]                 |LOC    |
# |20 |Route de Saint Etienne du Bois   |[Saint Etienne du Bois]          |LOC    |
# |21 |Rue de la Tour                   |[Rue de la Tour]                 |LOC    |
# |22 |Rue de la Rogeraie               |[Rue de la Rogeraie]             |LOC    |
# |23 |Chemin sous la Ville             |[Ville]                          |LOC    |
# |24 |418 Chemin du Chataignier        |[418 Chemin du Chataignier]      |MISC   |
# |25 |Impasse des Irantelles           |[Irantelles]                     |MISC   |
# |26 |34 Impasse du Plat               |[34 Impasse du Plat]             |MISC   |
# |27 |Chemin Vionnet des Places        |[Chemin Vionnet, Places]         |PER    |
# |27 |Chemin Vionnet des Places        |[Chemin Vionnet, Places]         |LOC    |
# |28 |95 Rue des Ecoles                |[Rue des Ecoles]                 |LOC    |
# |29 |Rue des Morilles                 |[Rue des Morilles]               |LOC    |
# |30 |5 Avenue des Tilleuls            |[5 Avenue des Tilleuls]          |LOC    |
# |31 |961 Chemin de Corneloup          |[961 Chemin de Corneloup]        |LOC    |
# |32 |408 Route de Lyon                |[408 Route de Lyon]              |LOC    |
# |33 |Allee du Cubilot                 |[Allee du Cubilot]               |LOC    |
# |34 |90 Chemin de la Fontaine         |[90 Chemin de la Fontaine]       |LOC    |
# |35 |Rue Bombec                       |[Rue Bombec]                     |LOC    |
# |36 |Lotissement Genevriers l’Europe  |[Genevriers l’Europe]            |PER    |
# |37 |Chemin Levé                      |[Chemin Levé]                    |MISC   |
# |38 |Rue de Cornier                   |[Rue de Cornier]                 |LOC    |
# |39 |424 Route de Marmont             |[Route de Marmont]               |LOC    |
# |40 |Impasse des Irantelles           |[Irantelles]                     |MISC   |
# |41 |La Rue                           |[Rue]                            |LOC    |
# |42 |Route de la Boisse               |[Boisse]                         |LOC    |
# |43 |Rue de la Lilette                |[Rue de la Lilette]              |PER    |
# |44 |9 Lotissement du Janivon         |[Janivon]                        |LOC    |
# |45 |30 Rue Principale                |[Rue Principale]                 |LOC    |
# |46 |143 Chemin des Liavins           |[143 Chemin des Liavins]         |MISC   |
# |47 |410 Rue du Saugey                |[Rue du Saugey]                  |LOC    |
# |48 |Rue du Chateau des Bains         |[Rue du Chateau des Bains]       |LOC    |
# |49 |Chemin Vie de Vaise              |[Chemin Vie de Vaise]            |MISC   |
# |50 |2 Rue des Barmettes              |[2 Rue des Barmettes]            |MISC   |
# |51 |Grande Rue                       |[Grande Rue]                     |LOC    |
# |52 |80 Grande Rue                    |[80 Grande Rue]                  |MISC   |
# |53 |Grande Rue                       |[Grande Rue]                     |LOC    |
# |54 |Rue de la Tour                   |[Rue de la Tour]                 |LOC    |
# |55 |Rue des Cèpes                    |[Rue des Cèpes]                  |LOC    |
# |56 |Lotissement les Loups            |[Loups]                          |ORG    |
# |57 |Au Dessus de la Roche            |[Dessus de la Roche]             |MISC   |
# |58 |4 Route de Divonne               |[4 Route de Divonne]             |LOC    |
# |59 |Rue Principale Vaux Fevroux      |[Rue Principale Vaux Fevroux]    |LOC    |
# |60 |Rue du Dauphiné                  |[Dauphiné]                       |LOC    |
# |61 |338 Rue du Village               |[Rue du Village]                 |LOC    |
# |62 |5 Rue de L Ecole                 |[Rue de L Ecole]                 |LOC    |
# |63 |Route des Dames                  |[Route des Dames]                |LOC    |
# |64 |Route de Poncin                  |[Poncin]                         |LOC    |
# |65 |3 Place Honore d’Urfe            |[3 Place Honore d’Urfe]          |LOC    |
# |66 |81 Rue Traversière               |[81 Rue Traversière]             |LOC    |
# |67 |Grande Rue                       |[Grande Rue]                     |LOC    |
# |68 |Chemin de Saint Michel           |[Saint Michel]                   |LOC    |
# |69 |Rue des Grenodieres              |[Rue des Grenodieres]            |LOC    |
# |70 |Rue Paul Blanc                   |[Rue Paul Blanc]                 |LOC    |
# |71 |2100 Chemin de Tanvol            |[2100 Chemin de Tanvol]          |MISC   |
# |72 |175 Rue de l’Etang               |[Rue de l’Etang]                 |LOC    |
# |73 |22 Rue Aristide Briand           |[22 Rue Aristide Briand]         |ORG    |
# |74 |55 Impasse des Noisettes         |[55 Impasse des Noisettes]       |MISC   |
# |75 |Route de Prou                    |[Route de Prou]                  |LOC    |
# |76 |Chemin de la Charrière           |[Charrière]                      |LOC    |
# |77 |Enceinte Buyaz                   |[Buyaz]                          |PER    |
# |78 |Allée des Alouettes              |[Allée des Alouettes]            |LOC    |
# |79 |Rue du Puits Mathieu             |[Rue du Puits Mathieu]           |LOC    |
# |80 |Lotissement Bois Joli            |[Bois, Joli]                     |PER    |
# |80 |Lotissement Bois Joli            |[Bois, Joli]                     |PER    |
# |81 |Route du Logis Neuf              |[Logis Neuf]                     |LOC    |
# |82 |4 Impasse du Quart d’Amont       |[4 Impasse du Quart d’Amont]     |MISC   |
# |83 |47 Rue du Vieux Quartier Latin   |[47 Rue, Vieux Quartier Latin]   |LOC    |
# |83 |47 Rue du Vieux Quartier Latin   |[47 Rue, Vieux Quartier Latin]   |LOC    |
# |84 |879 Chemin de l’Aigrefeuille     |[879 Chemin de l’Aigrefeuille]   |MISC   |
# |85 |421 Voie du Tram                 |[Voie du Tram]                   |LOC    |
# |86 |34 Rue des Chaumes               |[34 Rue des Chaumes]             |LOC    |
# |87 |935 Chemin de la Cotiere         |[Chemin de la Cotiere]           |LOC    |
# |88 |Montee de l’Orme                 |[Montee de l’Orme]               |PER    |
# |89 |2 Place du Champ de Mars         |[2 Place du Champ de Mars]       |LOC    |
# |90 |Rue Centrale                     |[Rue Centrale]                   |LOC    |
# |91 |41 Rue des Genetes               |[41 Rue des Genetes]             |LOC    |
# |92 |Rue du Port                      |[Rue du Port]                    |LOC    |
# |93 |276 Allee de la Geliere          |[Allee de la Geliere]            |LOC    |
# |94 |5 Janivon                        |[Janivon]                        |PER    |
# |95 |913 Chemin de l’Aigrefeuille     |[913 Chemin de l’Aigrefeuille]   |LOC    |
# |96 |19 Avenue du Général de Gaulle   |[19 Avenue du Général de Gaulle] |LOC    |
# |97 |1020 Rue de Majornas             |[Rue de Majornas]                |LOC    |
# |98 |1035 Route de la Dombes          |[1035 Route de la Dombes]        |LOC    |
# |99 |Rue Joli Bugey                   |[Rue Joli Bugey]                 |LOC    |
# |100|274 Route de la Corias           |[Route de la Corias]             |LOC    |
# |101|Rue de l’Artisanat               |[Rue de l’Artisanat]             |LOC    |
# |102|80 Rue Amédée Bonnet             |[Rue Amédée Bonnet]              |LOC    |
# |103|Route des Echets                 |[Route des Echets]               |LOC    |
# |104|Lotissement les Thiars           |[Thiars]                         |MISC   |
# |105|Rue de Fenières                  |[Rue de Fenières]                |LOC    |
# |106|980 Che d’Agnereins              |[Che]                            |PER    |
# |107|80 Montée du Four                |[80 Montée du Four]              |MISC   |
# |108|Route de Trevoux                 |[Route de Trevoux]               |LOC    |
# |109|Chemin de la Fin                 |[Chemin de la Fin]               |LOC    |
# |110|346 Route du Boissonnet          |[346 Route du Boissonnet]        |LOC    |
# |111|60 Rue Alexandre Bérard          |[60 Rue Alexandre Bérard]        |LOC    |
# |112|12 Rue Antoine Buy               |[12 Rue Antoine Buy]             |ORG    |
# |113|Rue du Tilleul                   |[Rue du Tilleul]                 |LOC    |
# |114|Lotissement le Picardet          |[Picardet]                       |MISC   |
# |115|109 Montée des Cannes            |[109 Montée des Cannes]          |MISC   |
# |116|Chemin de Grammon                |[Chemin de Grammon]              |MISC   |
# |117|60 Lotissement de la Croix Trieux|[Lotissement, Croix Trieux]      |LOC    |
# |117|60 Lotissement de la Croix Trieux|[Lotissement, Croix Trieux]      |LOC    |
# |118|Grande Rue                       |[Grande Rue]                     |LOC    |
# |119|Rue des Rouges-Gorges            |[Rue des Rouges-Gorges]          |LOC    |
# |120|3 Chemin de la Dame Louise       |[3 Chemin de la Dame Louise]     |MISC   |
# |121|6 Rocade des Carrés              |[6 Rocade, Carrés]               |LOC    |
# |121|6 Rocade des Carrés              |[6 Rocade, Carrés]               |LOC    |
# |122|40 Rue Aristide Briand           |[40 Rue Aristide Briand]         |LOC    |
# |123|Rue des Champs Fleuris           |[Rue, Champs Fleuris]            |LOC    |
# |123|Rue des Champs Fleuris           |[Rue, Champs Fleuris]            |LOC    |
# |124|Chemin de Gaz de Banc            |[Gaz de Banc]                    |ORG    |
# |125|Rue des Dentines                 |[Rue des Dentines]               |LOC    |
# |126|19 Lotissement En Marmoerain     |[Lotissement En Marmoerain]      |MISC   |
# |127|140 Chemin du Mont Riant         |[Mont Riant]                     |LOC    |
# |128|Impasse du Colomier              |[Colomier]                       |LOC    |
# |129|Rue des Noyers                   |[Rue des Noyers]                 |PER    |
# |130|836 Route d’Hauteville           |[Route d’Hauteville]             |LOC    |
# |131|Lotissement Clos des Bouviers I  |[Lotissement Clos des Bouviers I]|MISC   |
# |132|Fay                              |[Fay]                            |PER    |
# |133|37 Lotissement le Clos des Frênes|[Clos des Frênes]                |LOC    |
# |134|189 Rue du Prémonin              |[Rue du Prémonin]                |LOC    |
# |135|Rue de la Cigogne                |[Rue de la Cigogne]              |LOC    |
# |136|15 Rue Alexandre Bérard          |[15 Rue Alexandre Bérard]        |LOC    |
# |137|Grande Rue                       |[Grande Rue]                     |LOC    |
# |138|21 Rue de la Fruitière           |[21 Rue de la Fruitière]         |LOC    |
# |139|Quai du Buizin                   |[Buizin]                         |LOC    |
# |140|17 Rue Henri Dunant              |[17 Rue Henri Dunant]            |LOC    |
# |141|Boulevard des Combattants        |[Boulevard des Combattants]      |LOC    |
# |142|128 Rue Louis Lepine             |[Rue Louis Lepine]               |LOC    |
# |143|9 Genevriers le Petit Verger     |[9 Genevriers, Petit Verger]     |LOC    |
# |143|9 Genevriers le Petit Verger     |[9 Genevriers, Petit Verger]     |LOC    |
# |144|12 Lotissement En Marmoerain     |[12 Lotissement En Marmoerain]   |MISC   |
# |145|142 Allée de la Panissette       |[142 Allée de la Panissette]     |MISC   |
# |146|Rue Neuve                        |[Rue Neuve]                      |LOC    |
# |147|Chemin de l’Ouche                |[l’Ouche]                        |LOC    |
# |148|Saint-Lazare                     |[Saint-Lazare]                   |LOC    |
# |149|Rue de Fenières                  |[Rue de Fenières]                |LOC    |
# |150|4 Lot les Jardins D Agathe       |[4 Lot, Jardins D Agathe]        |LOC    |
# |150|4 Lot les Jardins D Agathe       |[4 Lot, Jardins D Agathe]        |LOC    |
# |151|Chemin du Vezely                 |[Vezely]                         |LOC    |
# |152|29 Rue Henri Dunant              |[29 Rue Henri Dunant]            |LOC    |
# |153|126 Chemin des Gremelieres       |[Gremelieres]                    |LOC    |
# |154|Chemin des Bourdonnieres         |[Bourdonnieres]                  |MISC   |
# |155|Rue des Sources                  |[Rue des Sources]                |LOC    |
# |156|Rue des Rossignols               |[Rue des Rossignols]             |LOC    |
# |157|Rue Pre de Fontaine              |[Rue Pre, Fontaine]              |MISC   |
# |157|Rue Pre de Fontaine              |[Rue Pre, Fontaine]              |PER    |
# |158|223 Rue Alexandre Bérard         |[223 Rue Alexandre Bérard]       |LOC    |
# |159|Rue des Renardes                 |[Rue des Renardes]               |LOC    |
# |160|78 Chemin du Pré de la Ville     |[78 Chemin du Pré de la Ville]   |LOC    |
# |161|35 Rue des Mouettes              |[35 Rue des Mouettes]            |LOC    |
# |162|155 Chemin des Cadalles          |[155 Chemin des Cadalles]        |MISC   |
# |163|43 Rue Georges Guynemer          |[43 Rue Georges Guynemer]        |LOC    |
# |164|191 Rue du Tiret                 |[Rue du Tiret]                   |LOC    |
# |165|83 Chemin de la Grange Neuve     |[83 Chemin, Grange Neuve]        |LOC    |
# |165|83 Chemin de la Grange Neuve     |[83 Chemin, Grange Neuve]        |LOC    |
# |166|58 Chemin du Hameau              |[58 Chemin du Hameau]            |LOC    |
# |167|90 Montée des Cannes             |[90 Montée des Cannes]           |MISC   |
# |168|56 Allee de l’Etrac              |[Allee de l’Etrac]               |LOC    |
# |169|Rue de Buffières                 |[Rue de Buffières]               |LOC    |
# |170|92 Route de Bourg                |[92 Route de Bourg]              |LOC    |
# |171|Chemin de la Pralet              |[Pralet]                         |LOC    |
# |172|Impasse du Capite                |[Capite]                         |LOC    |
# |173|41 Chemin En Martel              |[En Martel]                      |MISC   |
# |174|560 Rue Royale                   |[Rue Royale]                     |LOC    |
# |175|Route de Grand Corent            |[Grand Corent]                   |LOC    |
# |176|Le Clos des Dombes               |[Clos des Dombes]                |LOC    |
# |177|14 Allee Andre Charles Boulle    |[14 Allee Andre Charles Boulle]  |MISC   |
# |178|86 Rue du Molaret                |[Rue du Molaret]                 |LOC    |
# |179|278 Route de Saint Trivier       |[Route de Saint Trivier]         |LOC    |
# |180|Grande Rue                       |[Grande Rue]                     |LOC    |
# |181|179 Route de Laval               |[179 Route de Laval]             |LOC    |
# |182|Chemin du Vallon des Planches    |[Vallon des Planches]            |LOC    |
# |183|Rue des Mesanges                 |[Rue des Mesanges]               |LOC    |
# |184|Rue Neuve                        |[Rue Neuve]                      |LOC    |
# |185|223 Rue des Brotteaux            |[223 Rue des Brotteaux]          |LOC    |
# |186|3 Avenue de Verdun               |[3 Avenue de Verdun]             |MISC   |
# |187|10 Rue Bellievre                 |[10 Rue Bellievre]               |LOC    |
# |188|La Creuz                         |[Creuz]                          |LOC    |
# |189|Impasse des Magnolias            |[Magnolias]                      |MISC   |
# +---+---------------------------------+---------------------------------+-------+
# only showing top 200 rows

# %%
result = result.groupby("id").agg(F.collect_set('result'), F.collect_list('predict'))
result.orderBy('id').show(n = 200, truncate = False)
# Out:
# +---+-----------------------------------+---------------------+
# |id |collect_set(result)                |collect_list(predict)|
# +---+-----------------------------------+---------------------+
# |0  |[[Route de Trevoux]]               |[LOC]                |
# |1  |[[Rue Sainte Marie]]               |[LOC]                |
# |2  |[[Route d’Hauteville]]             |[LOC]                |
# |3  |[[Route du Morbier]]               |[LOC]                |
# |4  |[[Rue des Bleuets]]                |[LOC]                |
# |5  |[[7 Rue Jean Monnet]]              |[LOC]                |
# |6  |[[Chemin de Chavagneux]]           |[LOC]                |
# |7  |[[55 Rue du Coteau]]               |[LOC]                |
# |8  |[[Rue de l’Eglise]]                |[LOC]                |
# |9  |[[89 Impasse des Chênes]]          |[MISC]               |
# |10 |[[Rue du Journans]]                |[LOC]                |
# |11 |[[Rue de la Rogeraie]]             |[LOC]                |
# |12 |[[Bourg]]                          |[LOC]                |
# |13 |[[12 Rue Jean Emery]]              |[LOC]                |
# |14 |[[Dauphiné]]                       |[LOC]                |
# |15 |[[162 Route de Bottenay]]          |[LOC]                |
# |16 |[[Rue de la Doy]]                  |[LOC]                |
# |17 |[[Rue des Colonnes]]               |[LOC]                |
# |18 |[[541 Route du Boissonnet]]        |[LOC]                |
# |19 |[[Route de Bourg]]                 |[LOC]                |
# |20 |[[Saint Etienne du Bois]]          |[LOC]                |
# |21 |[[Rue de la Tour]]                 |[LOC]                |
# |22 |[[Rue de la Rogeraie]]             |[LOC]                |
# |23 |[[Ville]]                          |[LOC]                |
# |24 |[[418 Chemin du Chataignier]]      |[MISC]               |
# |25 |[[Irantelles]]                     |[MISC]               |
# |26 |[[34 Impasse du Plat]]             |[MISC]               |
# |27 |[[Chemin Vionnet, Places]]         |[PER, LOC]           |
# |28 |[[Rue des Ecoles]]                 |[LOC]                |
# |29 |[[Rue des Morilles]]               |[LOC]                |
# |30 |[[5 Avenue des Tilleuls]]          |[LOC]                |
# |31 |[[961 Chemin de Corneloup]]        |[LOC]                |
# |32 |[[408 Route de Lyon]]              |[LOC]                |
# |33 |[[Allee du Cubilot]]               |[LOC]                |
# |34 |[[90 Chemin de la Fontaine]]       |[LOC]                |
# |35 |[[Rue Bombec]]                     |[LOC]                |
# |36 |[[Genevriers l’Europe]]            |[PER]                |
# |37 |[[Chemin Levé]]                    |[MISC]               |
# |38 |[[Rue de Cornier]]                 |[LOC]                |
# |39 |[[Route de Marmont]]               |[LOC]                |
# |40 |[[Irantelles]]                     |[MISC]               |
# |41 |[[Rue]]                            |[LOC]                |
# |42 |[[Boisse]]                         |[LOC]                |
# |43 |[[Rue de la Lilette]]              |[PER]                |
# |44 |[[Janivon]]                        |[LOC]                |
# |45 |[[Rue Principale]]                 |[LOC]                |
# |46 |[[143 Chemin des Liavins]]         |[MISC]               |
# |47 |[[Rue du Saugey]]                  |[LOC]                |
# |48 |[[Rue du Chateau des Bains]]       |[LOC]                |
# |49 |[[Chemin Vie de Vaise]]            |[MISC]               |
# |50 |[[2 Rue des Barmettes]]            |[MISC]               |
# |51 |[[Grande Rue]]                     |[LOC]                |
# |52 |[[80 Grande Rue]]                  |[MISC]               |
# |53 |[[Grande Rue]]                     |[LOC]                |
# |54 |[[Rue de la Tour]]                 |[LOC]                |
# |55 |[[Rue des Cèpes]]                  |[LOC]                |
# |56 |[[Loups]]                          |[ORG]                |
# |57 |[[Dessus de la Roche]]             |[MISC]               |
# |58 |[[4 Route de Divonne]]             |[LOC]                |
# |59 |[[Rue Principale Vaux Fevroux]]    |[LOC]                |
# |60 |[[Dauphiné]]                       |[LOC]                |
# |61 |[[Rue du Village]]                 |[LOC]                |
# |62 |[[Rue de L Ecole]]                 |[LOC]                |
# |63 |[[Route des Dames]]                |[LOC]                |
# |64 |[[Poncin]]                         |[LOC]                |
# |65 |[[3 Place Honore d’Urfe]]          |[LOC]                |
# |66 |[[81 Rue Traversière]]             |[LOC]                |
# |67 |[[Grande Rue]]                     |[LOC]                |
# |68 |[[Saint Michel]]                   |[LOC]                |
# |69 |[[Rue des Grenodieres]]            |[LOC]                |
# |70 |[[Rue Paul Blanc]]                 |[LOC]                |
# |71 |[[2100 Chemin de Tanvol]]          |[MISC]               |
# |72 |[[Rue de l’Etang]]                 |[LOC]                |
# |73 |[[22 Rue Aristide Briand]]         |[ORG]                |
# |74 |[[55 Impasse des Noisettes]]       |[MISC]               |
# |75 |[[Route de Prou]]                  |[LOC]                |
# |76 |[[Charrière]]                      |[LOC]                |
# |77 |[[Buyaz]]                          |[PER]                |
# |78 |[[Allée des Alouettes]]            |[LOC]                |
# |79 |[[Rue du Puits Mathieu]]           |[LOC]                |
# |80 |[[Bois, Joli]]                     |[PER, PER]           |
# |81 |[[Logis Neuf]]                     |[LOC]                |
# |82 |[[4 Impasse du Quart d’Amont]]     |[MISC]               |
# |83 |[[47 Rue, Vieux Quartier Latin]]   |[LOC, LOC]           |
# |84 |[[879 Chemin de l’Aigrefeuille]]   |[MISC]               |
# |85 |[[Voie du Tram]]                   |[LOC]                |
# |86 |[[34 Rue des Chaumes]]             |[LOC]                |
# |87 |[[Chemin de la Cotiere]]           |[LOC]                |
# |88 |[[Montee de l’Orme]]               |[PER]                |
# |89 |[[2 Place du Champ de Mars]]       |[LOC]                |
# |90 |[[Rue Centrale]]                   |[LOC]                |
# |91 |[[41 Rue des Genetes]]             |[LOC]                |
# |92 |[[Rue du Port]]                    |[LOC]                |
# |93 |[[Allee de la Geliere]]            |[LOC]                |
# |94 |[[Janivon]]                        |[PER]                |
# |95 |[[913 Chemin de l’Aigrefeuille]]   |[LOC]                |
# |96 |[[19 Avenue du Général de Gaulle]] |[LOC]                |
# |97 |[[Rue de Majornas]]                |[LOC]                |
# |98 |[[1035 Route de la Dombes]]        |[LOC]                |
# |99 |[[Rue Joli Bugey]]                 |[LOC]                |
# |100|[[Route de la Corias]]             |[LOC]                |
# |101|[[Rue de l’Artisanat]]             |[LOC]                |
# |102|[[Rue Amédée Bonnet]]              |[LOC]                |
# |103|[[Route des Echets]]               |[LOC]                |
# |104|[[Thiars]]                         |[MISC]               |
# |105|[[Rue de Fenières]]                |[LOC]                |
# |106|[[Che]]                            |[PER]                |
# |107|[[80 Montée du Four]]              |[MISC]               |
# |108|[[Route de Trevoux]]               |[LOC]                |
# |109|[[Chemin de la Fin]]               |[LOC]                |
# |110|[[346 Route du Boissonnet]]        |[LOC]                |
# |111|[[60 Rue Alexandre Bérard]]        |[LOC]                |
# |112|[[12 Rue Antoine Buy]]             |[ORG]                |
# |113|[[Rue du Tilleul]]                 |[LOC]                |
# |114|[[Picardet]]                       |[MISC]               |
# |115|[[109 Montée des Cannes]]          |[MISC]               |
# |116|[[Chemin de Grammon]]              |[MISC]               |
# |117|[[Lotissement, Croix Trieux]]      |[LOC, LOC]           |
# |118|[[Grande Rue]]                     |[LOC]                |
# |119|[[Rue des Rouges-Gorges]]          |[LOC]                |
# |120|[[3 Chemin de la Dame Louise]]     |[MISC]               |
# |121|[[6 Rocade, Carrés]]               |[LOC, LOC]           |
# |122|[[40 Rue Aristide Briand]]         |[LOC]                |
# |123|[[Rue, Champs Fleuris]]            |[LOC, LOC]           |
# |124|[[Gaz de Banc]]                    |[ORG]                |
# |125|[[Rue des Dentines]]               |[LOC]                |
# |126|[[Lotissement En Marmoerain]]      |[MISC]               |
# |127|[[Mont Riant]]                     |[LOC]                |
# |128|[[Colomier]]                       |[LOC]                |
# |129|[[Rue des Noyers]]                 |[PER]                |
# |130|[[Route d’Hauteville]]             |[LOC]                |
# |131|[[Lotissement Clos des Bouviers I]]|[MISC]               |
# |132|[[Fay]]                            |[PER]                |
# |133|[[Clos des Frênes]]                |[LOC]                |
# |134|[[Rue du Prémonin]]                |[LOC]                |
# |135|[[Rue de la Cigogne]]              |[LOC]                |
# |136|[[15 Rue Alexandre Bérard]]        |[LOC]                |
# |137|[[Grande Rue]]                     |[LOC]                |
# |138|[[21 Rue de la Fruitière]]         |[LOC]                |
# |139|[[Buizin]]                         |[LOC]                |
# |140|[[17 Rue Henri Dunant]]            |[LOC]                |
# |141|[[Boulevard des Combattants]]      |[LOC]                |
# |142|[[Rue Louis Lepine]]               |[LOC]                |
# |143|[[9 Genevriers, Petit Verger]]     |[LOC, LOC]           |
# |144|[[12 Lotissement En Marmoerain]]   |[MISC]               |
# |145|[[142 Allée de la Panissette]]     |[MISC]               |
# |146|[[Rue Neuve]]                      |[LOC]                |
# |147|[[l’Ouche]]                        |[LOC]                |
# |148|[[Saint-Lazare]]                   |[LOC]                |
# |149|[[Rue de Fenières]]                |[LOC]                |
# |150|[[4 Lot, Jardins D Agathe]]        |[LOC, LOC]           |
# |151|[[Vezely]]                         |[LOC]                |
# |152|[[29 Rue Henri Dunant]]            |[LOC]                |
# |153|[[Gremelieres]]                    |[LOC]                |
# |154|[[Bourdonnieres]]                  |[MISC]               |
# |155|[[Rue des Sources]]                |[LOC]                |
# |156|[[Rue des Rossignols]]             |[LOC]                |
# |157|[[Rue Pre, Fontaine]]              |[MISC, PER]          |
# |158|[[223 Rue Alexandre Bérard]]       |[LOC]                |
# |159|[[Rue des Renardes]]               |[LOC]                |
# |160|[[78 Chemin du Pré de la Ville]]   |[LOC]                |
# |161|[[35 Rue des Mouettes]]            |[LOC]                |
# |162|[[155 Chemin des Cadalles]]        |[MISC]               |
# |163|[[43 Rue Georges Guynemer]]        |[LOC]                |
# |164|[[Rue du Tiret]]                   |[LOC]                |
# |165|[[83 Chemin, Grange Neuve]]        |[LOC, LOC]           |
# |166|[[58 Chemin du Hameau]]            |[LOC]                |
# |167|[[90 Montée des Cannes]]           |[MISC]               |
# |168|[[Allee de l’Etrac]]               |[LOC]                |
# |169|[[Rue de Buffières]]               |[LOC]                |
# |170|[[92 Route de Bourg]]              |[LOC]                |
# |171|[[Pralet]]                         |[LOC]                |
# |172|[[Capite]]                         |[LOC]                |
# |173|[[En Martel]]                      |[MISC]               |
# |174|[[Rue Royale]]                     |[LOC]                |
# |175|[[Grand Corent]]                   |[LOC]                |
# |176|[[Clos des Dombes]]                |[LOC]                |
# |177|[[14 Allee Andre Charles Boulle]]  |[MISC]               |
# |178|[[Rue du Molaret]]                 |[LOC]                |
# |179|[[Route de Saint Trivier]]         |[LOC]                |
# |180|[[Grande Rue]]                     |[LOC]                |
# |181|[[179 Route de Laval]]             |[LOC]                |
# |182|[[Vallon des Planches]]            |[LOC]                |
# |183|[[Rue des Mesanges]]               |[LOC]                |
# |184|[[Rue Neuve]]                      |[LOC]                |
# |185|[[223 Rue des Brotteaux]]          |[LOC]                |
# |186|[[3 Avenue de Verdun]]             |[MISC]               |
# |187|[[10 Rue Bellievre]]               |[LOC]                |
# |188|[[Creuz]]                          |[LOC]                |
# |189|[[Magnolias]]                      |[MISC]               |
# |190|[[Sainte Olive]]                   |[PER]                |
# |191|[[Pré Vert]]                       |[LOC]                |
# |192|[[58 Rue Aristide Briand]]         |[ORG]                |
# |193|[[8 Allee du Buidon]]              |[LOC]                |
# |194|[[Rue du Château]]                 |[LOC]                |
# |195|[[Rue Neuve]]                      |[LOC]                |
# |196|[[Rue du Besson]]                  |[LOC]                |
# |197|[[Rue des Battieres]]              |[LOC]                |
# |198|[[Allee des Rubis]]                |[LOC]                |
# |199|[[Rue de la Doraille]]             |[LOC]                |
# +---+-----------------------------------+---------------------+
# only showing top 200 rows
